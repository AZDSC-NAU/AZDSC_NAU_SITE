# %% [markdown]
# # **Exercise: Heart Disease Classification with Logistic Regression, Random Forests, and Neural Networks**
#
# ---
#
# In this notebook, you will follow the ML project lifecycle to develop and evaluate classification models for predicting heart disease using the UCI `Heart Disease` dataset, available at https://archive.ics.uci.edu/dataset/45/heart+disease. As an extension, you will incorporate **all categorical features** in the dataset, applying appropriate encoding techniques where necessary. You will then evaluate how the inclusion of these features affects model performance.
#
# Your notebook in this exercise needs to demonstrate data exploration, data preprocessing, model training, performance evaluation, and model comparison. You will build and assess three classification models:
#
# - Logistic Regression
# - Random Forest
# - Fully Connected Neural Network (multiple Hidden Layers)
#
# Model performance will be evaluated using metrics such as **accuracy** and **area under the ROC curve (AUC)**. After reproducing the baseline results, you will investigate how model design choices and hyperparameter settings affect predictive performance. In particular, you will experiment with tuning the hyperparameters of the **Random Forest** and **Neural Network** models to improve their accuracy and AUC on the test data.
#
# Through this exercise, you will gain hands-on experience with the ML workflow, model evaluation, feature engineering, and hyperparameter tuning while working on a real-world classification problem.

# %% [markdown]
# ### **S0. Data Import and Processing**

# %%
# Install the ucimlrepo package to access the 'Heart Disease' dataset
# !pip install ucimlrepo

# Import function to fetch the dataset: Heart Disease at https://archive.ics.uci.edu/dataset/45/heart+disease
from ucimlrepo import fetch_ucirepo

# %%
# Fetch the dataset
heart_disease = fetch_ucirepo(name='Heart Disease')

# %% [markdown]
# ### **S1. Data Visualization**

# %% [markdown]
# ### **S2. Logistic Regression**

# %% [markdown]
# ### **S3. Random Forest**

# %% [markdown]
# ### **S4. Fully Connected NN with Multiple Hidden Layers**
